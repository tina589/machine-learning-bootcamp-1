# %% [markdown]
# <a href="https://colab.research.google.com/github/tina589/machine-learning-bootcamp-1/blob/main/supervised/01_basic/02_missing_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import bibliotek**

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.2.2'

# %% [markdown]
# **Wygenerowanie danych**

# %%
data = {
    'size': ['XL', 'L', 'M', np.nan, 'M', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red', 'green'],
    'gender': ['female', 'male', np.nan, 'female', 'female', 'male'],
    'price': [ 199.0, 89.0, np.nan, 129.0, 79.0, 89.0],
    'weight': [500, 450, 300, np.nan, 410, np.nan],
    'bought': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %% [markdown]
# **Utworzenie kopii danych**

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   6 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  4 non-null      float64
#  5   bought  6 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 416.0+ bytes

# %% [markdown]
# **Sprawdzenie braków**

# %%
df.isnull()
# Out:
#     size  color  gender  price  weight  bought
# 0  False  False   False  False   False   False
# 1  False  False   False  False   False   False
# 2  False  False    True   True   False   False
# 3   True  False   False  False    True   False
# 4  False  False   False  False   False   False
# 5  False  False   False  False    True   False

# %%
df.isnull().sum()
# Out:
# size      1
# color     0
# gender    1
# price     1
# weight    2
# bought    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %% [markdown]
# Sprawdzenie procentu braków danych

# %%
df.isnull().sum() / len(df)
# Out:
# size      0.166667
# color     0.000000
# gender    0.166667
# price     0.166667
# weight    0.333333
# bought    0.000000
# dtype: float64

# %% [markdown]
# **SimpleImputer - klasa pozwalająca na proste uzupełnianie braków danych**

# %%
from sklearn.impute import SimpleImputer

#strategy: 'mean', 'median', 'most_frequent', 'constant'
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(df[['weight']])
# Out:
# SimpleImputer()

# %%
imputer.statistics_
# Out:
# array([415.])

# %% [markdown]
# Zastąpienie np.nan średnią wagą:

# %%
imputer.transform(df[['weight']])
# Out:
# array([[500.],
#        [450.],
#        [300.],
#        [415.],
#        [410.],
#        [415.]])

# %% [markdown]
# Przypisanie zmiennej:

# %%
df['weight'] = imputer.transform(df[['weight']])
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %% [markdown]
# Uzupełnienie kolumny price:

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=99.0)
imputer.fit_transform(df[['price']]) #połączenie fit i transform
# Out:
# array([[199.],
#        [ 89.],
#        [ 99.],
#        [129.],
#        [ 79.],
#        [ 89.]])

# %% [markdown]
# Uzupełnienie kolumny size:

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='L')
imputer.fit_transform(df[['size']])
# Out:
# array([['XL'],
#        ['L'],
#        ['M'],
#        ['L'],
#        ['M'],
#        ['M']], dtype=object)

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0   415.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0   415.0     no

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit_transform(df[['size']])
# Out:
# array([['XL'],
#        ['L'],
#        ['M'],
#        ['M'],
#        ['M'],
#        ['M']], dtype=object)

# %%
df = df_raw.copy()
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
df.isnull().sum()
# Out:
# size      1
# color     0
# gender    1
# price     1
# weight    2
# bought    0
# dtype: int64

# %%
pd.isnull(df['weight']) #działanie na kolumnie weight
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: weight, dtype: bool

# %%
df[pd.isnull(df['weight'])] #zwraca wiersze, gdzie jest problem z wagą
# Out:
#   size  color  gender  price  weight bought
# 3  NaN  green  female  129.0     NaN     no
# 5    M  green    male   89.0     NaN     no

# %%
df[~pd.isnull(df['weight'])] #zwraca wierwsze, gdzie NIE MA problemów z wagą
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 4    M    red  female   79.0   410.0    yes

# %%
pd.notnull(df['weight']) #zwraca prawdę, gdy dane są i fałsz, gdy danych nie ma
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: weight, dtype: bool

# %%
df[pd.notnull(df['weight'])]
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 4    M    red  female   79.0   410.0    yes

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3  NaN  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
df.fillna(value='brak') #uzupełnianie automatycznie wszystkich braków danych
# Out:
#    size  color  gender  price weight bought
# 0    XL    red  female  199.0  500.0    yes
# 1     L  green    male   89.0  450.0     no
# 2     M   blue    brak   brak  300.0    yes
# 3  brak  green  female  129.0   brak     no
# 4     M    red  female   79.0  410.0    yes
# 5     M  green    male   89.0   brak     no

# %%
df.fillna(value=0.0)
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     0.0    0.0   300.0    yes
# 3  0.0  green  female  129.0     0.0     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     0.0     no

# %%
df['size'].fillna(value='L', inplace=True) #fillna na kolumnie size, zmiany zostaną wykonane na kolumnie, nie trzeba przypisywać
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue     NaN    NaN   300.0    yes
# 3    L  green  female  129.0     NaN     no
# 4    M    red  female   79.0   410.0    yes
# 5    M  green    male   89.0     NaN     no

# %%
df.dropna() #zwraca wiersze, gdzie są wszystkie dane; można kontrolować w parametrach, ile braków jest dopuszczalnych
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 4    M    red  female   79.0   410.0    yes

# %%
df = df.dropna() #przypisanie tylko tych wierszy, gdzie nie ma braków
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 4    M    red  female   79.0   410.0    yes

# %% [markdown]
# **BRAKI DANYCH W SZEREGACH CZASOWYCH**

# %%
data = {'price': [108,109,110,110,109, np.nan, np.nan, 112, 111, 111]}
date_range = pd.date_range(start = '01-01-2020 09:00', end = '01-01-2020 18:00', periods=10) #wygenerowanie szeregu czasowego

df = pd.DataFrame(data=data, index=date_range)
df
# Out:
#                      price
# 2020-01-01 09:00:00  108.0
# 2020-01-01 10:00:00  109.0
# 2020-01-01 11:00:00  110.0
# 2020-01-01 12:00:00  110.0
# 2020-01-01 13:00:00  109.0
# 2020-01-01 14:00:00    NaN
# 2020-01-01 15:00:00    NaN
# 2020-01-01 16:00:00  112.0
# 2020-01-01 17:00:00  111.0
# 2020-01-01 18:00:00  111.0

# %%
from pandas.plotting import register_matplotlib_converters  #importowanie bliblioteki z wykresami
import matplotlib.pyplot as plt
import seaborn as sns
register_matplotlib_converters()
sns.set()

plt.figure(figsize=(10,4))
plt.title('Braki danych')
_ = plt.plot(df.price)

# %%
import plotly.express as px #biblioteka pozwalająca na interaktywne wizualizacje

df_plotly = df.reset_index()
px.line(df_plotly, 'index', 'price', width=600, height=400,
        title = 'Szeregi czasowe - braki danych')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Usunięcie braków**

# %%
df_plotly = df_plotly.dropna()
px.line(df_plotly, 'index', 'price', width=600, height=400,
        title = 'Szeregi czasowe - braki danych')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Wypełnienie braków stałą wartością 0**

# %%
df_plotly = df.reset_index()
df_plotly['price_fill'] = df_plotly['price'].fillna(0)
px.line(df_plotly, 'index', 'price_fill', width=600, height=400,
        title = 'Szeregi czasowe - braki danych - wstawienie 0')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Wypełnienie braków średnią**

# %%
df_plotly = df.reset_index()
df_plotly['price_fill'] = df_plotly['price'].fillna(df_plotly['price'].mean())
px.line(df_plotly, 'index', 'price_fill', width=600, height=400,
        title='Szeregi czasowe - braki danych - wstawienie średniej')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Zastosowanie interpolacji**

# %%
df_plotly = df.reset_index()
df_plotly['price_fill'] = df_plotly['price'].interpolate()
px.line(df_plotly, 'index', 'price_fill', width=600, height=400,
        title='Szeregi czasowe - braki danych - interpolacja')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Wypełnienie braków metodą backward fill**

# %%
df_plotly = df.reset_index()
df_plotly['price_fill'] = df_plotly['price'].fillna(method='bfill')
px.line(df_plotly, 'index', 'price_fill', width=600, height=400,
        title='Szeregi czasowe - braki danych - backward fill')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **wypełnienie braków metodą forward fill**

# %%
df_plotly = df.reset_index()
df_plotly['price_fill'] = df_plotly['price'].fillna(method='ffill') #wstawianie poprzedniej wartosci w miejscu braku
px.line(df_plotly, 'index', 'price_fill', width=600, height=400,
        title='Szeregi czasowe - braki danych - forward fill')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
